# %% [markdown]
# ## Playing around with some data ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ### Importing some data ###

# %%
data = pd.read_csv("/Users/pk/odrive/Dropbox/Data Science/Winter 2018 - General Assembly/DSI/GA GitHub Materials/DC-flex-time/Blogging/blogging-exercise-data/huffpost-00c -Pres-45-Trump - Job Approval - National-poll-responses-clean.tsv", sep='\t')
data
# Out:
#       Approve  Disapprove  Undecided                       poll_slug  \
# 0        45.0        54.0        NaN                 rasmussen-28401
# 1        40.0        55.0        5.0                       cnn-28403
# 2         6.0        92.0        2.0                       cnn-28403
# 3        87.0         9.0        4.0                       cnn-28403
# 4        40.0        51.0       10.0                       cnn-28403
# 5        45.0        54.0        NaN                 rasmussen-28396
# 6        39.0        57.0        4.0                   nbc-wsj-28404
# 7        43.0        56.0        2.0              surveymonkey-28400
# 8         7.0        92.0        0.0              surveymonkey-28400
# 9        87.0        13.0        0.0              surveymonkey-28400
# 10       39.0        60.0        1.0              surveymonkey-28400
# 11       42.0        52.0        6.0          yougov-economist-28393
# 12       11.0        86.0        3.0          yougov-economist-28393
# ...
